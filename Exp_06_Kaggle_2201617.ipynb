# %% [markdown]
# <a href="https://colab.research.google.com/github/Sahildolas21/DSPY-Lab-Experiment/blob/main/Exp_06_Kaggle_2201617.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **1.Describe all three data set in terms of following : how many features, their categories (num,text,categorical, nominal,ordinal etc), number of tuples, missing values**
#
# **Answer :**
#
# **1. Air PolluƟon Dataset (World Air Quality Index)**
#
# Number of Features: Around 10–12 features (depends on preprocessing) Feature Types:
#
# Numerical: AQI, PM2.5, PM10, NO2, SO2, CO, O3 values
#
# Categorical/Nominal: City, Country
#
# DateƟme/Text: Date, Time
#
# Number of Tuples (Rows): ~30,000+ records (varies with dataset version) Missing Values:
#
# Present in several pollutant columns (PM2.5, PM10, etc.)
#
# Handled using techniques like dropping or imputaƟon
#
# **2. IRIS Dataset**
# Number of Features: 4 input features + 1 target feature Feature
# Types:
#
# Numerical: Sepal length, Sepal width, Petal length, Petal width
#
# Categorical/Nominal (Target): Species (Setosa, Versicolor, Virginica)
#
# Number of Tuples (Rows): 150 records Missing
#
# Values:
#
# No missing values (clean dataset)
#
# **3. Wine Quality Dataset (White Wine)**
#
# Number of Features: 11 input features + 1 output feature Feature
# Types:
#
# Numerical: Fixed acidity, volaƟle acidity, citric acid, residual sugar, chlorides, free sulfur dioxide,
#
# total sulfur dioxide, density, pH, sulphates, alcohol
#
# Ordinal (Target): Quality (score from 0–10)
#
# Number of Tuples (Rows): 4,898 records Missing
#
# Values:
#
# No missing values in most versions of dataset

# %% [markdown]
# **2.In IRIS data set which non graphical EDA is performed ?**
#
# **Answer :**
#
# Non-Graphical EDA in IRIS Dataset
#
# **1.Summary StaƟsƟcs (Descriptive Statistics)**
#
# * Mean, Median, Mode
# * Standard DeviaƟon, Variance
# * Minimum and Maximum values
# * Helps understand distribuƟon of features like sepal length, petal width, etc.
#
# **2.Measure of Central Tendency**
#
# * Mean, Median for each feature
# * Shows the central value of each numerical column
#
# **3.Measure of Dispersion**
#
# * Range, Variance, Standard DeviaƟon
# * Indicates spread of data
#
# **4.Class-wise AggregaƟon (GroupBy Analysis)**
#
# * Mean values of features for each species
# * Helps compare Setosa, Versicolor, Virginica
#
# **5.Correlation Analysis**
#
# * CorrelaƟon matrix between features
# Shows relaƟonships (e.g., petal length & petal width are highly correlated)
#
# **6.Checking Missing Values**
#
# * Using funcƟons like .isnull().sum()
# * Confirms dataset is clean (no missing values)
#
# **7.Data DistribuƟon (Frequency Count)**
#
# * Count of each species (target variable)
# * Shows dataset is balanced (50 samples per class)

# %% [markdown]
# **3.In  Air Quality data set which graph is used to perform multivariate analysis?**
#
# **Answer :**
#
# In the Air Quality dataset, the most commonly used graph for mulƟvariate analysis is:
#
# **1. Pair Plot (ScaƩer Plot Matrix)**
# * A pair plot shows relaƟonships between mulƟple variables at once.
# * It creates scaƩer plots for every pair of numerical features (like PM2.5, PM10, NO2, SO2,CO, etc.).
# * Diagonal elements usually show distribuƟon (histogram/KDE) of each variable.
#
# **2. Why it is used:**
# * Helps idenƟfy correlaƟon between pollutants
# * Detects paƩerns and trends among mulƟple variables
# * Useful for spoƫng outliers and clusters
#
# **3. Other MulƟvariate Graphs (someƟmes used):**
# * Heatmap (CorrelaƟon Matrix): Shows strength of relaƟonship between variables
# * 3D ScaƩer Plot: Used when analyzing 3 variables together

# %% [markdown]
# **4.In Wine quality data set can you do non graphical EDA ? Explain your answer.**
#
# **Answer :**
#
# **Yes**, non-graphical EDA can be performed on the Wine Quality dataset.
#
# **Explanation:** Non-graphical EDA involves analyzing data using staƟsƟcal and numerical methods without using visualizaƟons. In the Wine Quality dataset, this is effecƟvely done as follows:
#
# **1. Summary Statstcs**
#
# * Calculate mean, median, standard deviaƟon, min, max for all features like acidity, pH,alcohol, etc.
# * Helps understand overall data distribuƟon.
#
# **2. Measure of Central Tendency**
#
# * Mean and median values of each feature
# * Shows typical values of chemical properƟes in wine.
#
# **3. Measure of Dispersion**
#
# * Variance and standard deviaƟon
# * Helps idenƟfy how much the values vary
#
# **4. CorrelaƟon Analysis**
#
# * Compute correlaƟon matrix between features and quality
# * Helps idenƟfy important factors affecƟng wine quality (e.g., alcohol oŌen posiƟvely correlated).
#
# **5. Checking Missing Values**
#
# * Use funcƟons like .isnull().sum()
# * Confirms dataset is clean (usually no missing values)
#
# **6. Frequency DistribuƟon of Target Variable**
#
# * Count of each quality score (ordinal values from 0–10)
# * Helps understand class imbalance.
#
# **7. Group-wise Analysis**
#
# * Group data based on quality and calculate mean values
# * Helps compare chemical properƟes across different quality levels. Colab
